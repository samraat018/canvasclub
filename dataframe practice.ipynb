# %%
import os
import pandas as pd
import numpy as np

# %%
os.getcwd()
# Out:
# '/Users/samraatsingh/Desktop/Data Science/Canvas Eshank'

# %%
data=pd.read_json("employee_data.json")

# %%
data
# Out:
#                                               features
# 0    {'candidate': {'first_name': 'Margaret', 'last...
# 1    {'candidate': {'first_name': 'Michael', 'last_...
# 2    {'candidate': {'first_name': 'Brenda', 'last_n...
# 3    {'candidate': {'first_name': 'Joseph', 'last_n...
# 4    {'candidate': {'first_name': 'Laura', 'last_na...
# ..                                                 ...
# 495  {'candidate': {'first_name': 'Robert', 'last_n...
# 496  {'candidate': {'first_name': 'Lucas', 'last_na...
# 497  {'candidate': {'first_name': 'Kimberly', 'last...
# 498  {'candidate': {'first_name': 'Karla', 'last_na...
# 499  {'candidate': {'first_name': 'Mrs.', 'last_nam...
#
# [500 rows x 1 columns]

# %%
lst=[]
for i in data['features']:
    lst.append(i['candidate'])

a=pd.DataFrame(lst)

lst_headers=list(a.columns.values)
a
# Out:
#     first_name   last_name                                             skills  \
# 0     Margaret    Mcdonald                [skLearn, Java, R, SQL, Spark, C++]
# 1      Michael      Carter          [TensorFlow, R, Spark, MongoDB, C++, SQL]
# 2       Brenda       Tyler                                            [Spark]
# 3       Joseph        King  [skLearn, SQL, R, Spark, Java, C++, Python, Te...
# 4        Laura        Webb           [TensorFlow, C++, SQL, Java, R, MongoDB]
# ..         ...         ...                                                ...
# 495     Robert       Baker                        [skLearn, Spark, C++, Java]
# 496      Lucas       Brock                                              [C++]
# 497   Kimberly  Richardson                                     [Python, Java]
# 498      Karla     Salazar                   [MongoDB, Python, Java, skLearn]
# 499       Mrs.       Debra  [skLearn, R, MongoDB, Spark, TensorFlow, Java,...
#
# ...

# %%
lst
# Out:
# [{'first_name': 'Margaret',
#   'last_name': 'Mcdonald',
#   'skills': ['skLearn', 'Java', 'R', 'SQL', 'Spark', 'C++'],
#   'state': 'AL',
#   'specialty': 'Database',
#   'experience': 'Mid',
#   'relocation': 'no'},
#  {'first_name': 'Michael',
#   'last_name': 'Carter',
#   'skills': ['TensorFlow', 'R', 'Spark', 'MongoDB', 'C++', 'SQL'],
#   'state': 'AR',
#   'specialty': 'Statistics',
#   'experience': 'Senior',
#   'relocation': 'yes'},
#  {'first_name': 'Brenda',
#   'last_name': 'Tyler',
#   'skills': ['Spark'],
#   'state': 'UT',
#   'specialty': 'Database',
#   'experience': 'Mid',
#   'relocation': 'no'},
#  {'first_name': 'Joseph',
#   'last_name': 'King',
#   'skills': ['skLearn',
#    'SQL',
#    'R',
#    'Spark',
#    'Java',
#    'C++',
#    'Python',
#    'TensorFlow'],
#   'state': 'FL',
#   'specialty': 'Machine Learning',
#   'experience': 'Senior',
#   'relocation': 'maybe'},
#  {'first_name': 'Laura',
#   'last_name': 'Webb',
# ...

# %%
shortlist=pd.DataFrame()
lst=[]

for i in range(len(a["skills"])):
    if "R" in a["skills"][i] and "SQL" in a["skills"][i] and "Database"==a['specialty'][i] and "Senior"==a['experience'][i]:
        lst.append(data['features'][i]['candidate'])

shortlist=pd.DataFrame(lst)
            
print("Shortlisted candidates are as follow:\n")

shortlist
# Out:
# Shortlisted candidates are as follow:
#     first_name    last_name  \
# 0       George  Fitzpatrick
# 1   Jacqueline       Willis
# 2       Connor       Garcia
# 3       Ashley        Smith
# 4      Rebecca        Adams
# 5       Andrew         King
# 6        Sarah      Maxwell
# 7     Samantha       Miller
# 8       Wesley      Jackson
# 9       Tracey    Patterson
# 10    Danielle     Williams
# 11        John         Boyd
# 12      Meghan      Roberts
# 13        John       Walker
# 14    Jennifer       Harris
#
#                                                skills state specialty  \
# 0   [SQL, C++, Spark, R, skLearn, Python, MongoDB,...    ME  Database
# 1              [MongoDB, SQL, Python, Spark, R, Java]    ID  Database
# 2                           [skLearn, SQL, Python, R]    CT  Database
# 3   [C++, Spark, R, Java, MongoDB, Python, skLearn...    NM  Database
# 4   [C++, R, TensorFlow, Java, MongoDB, skLearn, SQL]    MA  Database
# ...

# %%
pd.DataFrame(data['features'][0]['candidate'])
# Out:
#   first_name last_name   skills state specialty experience relocation
# 0   Margaret  Mcdonald  skLearn    AL  Database        Mid         no
# 1   Margaret  Mcdonald     Java    AL  Database        Mid         no
# 2   Margaret  Mcdonald        R    AL  Database        Mid         no
# 3   Margaret  Mcdonald      SQL    AL  Database        Mid         no
# 4   Margaret  Mcdonald    Spark    AL  Database        Mid         no
# 5   Margaret  Mcdonald      C++    AL  Database        Mid         no

# %%
lst_headers=list(pd.DataFrame(data['features'][0]['candidate']).columns.values)

# %%
lst_headers
# Out:
# ['first_name',
#  'last_name',
#  'skills',
#  'state',
#  'specialty',
#  'experience',
#  'relocation']

# %%
df123=pd.DataFrame(columns=lst_headers)

# %%
df123
# Out:
# Empty DataFrame
# Columns: [first_name, last_name, skills, state, specialty, experience, relocation]
# Index: []

# %%
for i in range(len(data)):
    b=pd.DataFrame(data['features'][i]['candidate'])
    df123 = pd.concat([df123, b], ignore_index=True)

# %%
df123
# Out:
#      first_name last_name      skills state   specialty experience relocation
# 0      Margaret  Mcdonald     skLearn    AL    Database        Mid         no
# 1      Margaret  Mcdonald        Java    AL    Database        Mid         no
# 2      Margaret  Mcdonald           R    AL    Database        Mid         no
# 3      Margaret  Mcdonald         SQL    AL    Database        Mid         no
# 4      Margaret  Mcdonald       Spark    AL    Database        Mid         no
# ...         ...       ...         ...   ...         ...        ...        ...
# 2463       Mrs.     Debra  TensorFlow    TX  Statistics     Senior         no
# 2464       Mrs.     Debra        Java    TX  Statistics     Senior         no
# 2465       Mrs.     Debra         SQL    TX  Statistics     Senior         no
# 2466       Mrs.     Debra      Python    TX  Statistics     Senior         no
# 2467       Mrs.     Debra         C++    TX  Statistics     Senior         no
#
# [2468 rows x 7 columns]

# %%
df123[(df123.skills == 'R') & (df123.specialty == 'Statistics')]
# Out:
#      first_name last_name skills state   specialty experience relocation
# 7       Michael    Carter      R    AR  Statistics     Senior        yes
# 60        Tanya   Schultz      R    NV  Statistics        Mid        yes
# 96        Linda   Griffin      R    NE  Statistics     Junior         no
# 103       James    Mosley      R    AR  Statistics     Junior        yes
# 113      Rachel    Walker      R    TN  Statistics     Senior         no
# ...         ...       ...    ...   ...         ...        ...        ...
# 2234     Alyssa     Wells      R    AK  Statistics     Junior        yes
# 2295      David    Miller      R    MN  Statistics     Senior         no
# 2333      Haley      Reed      R    WY  Statistics     Junior         no
# 2358      Laura  Roberson      R    MA  Statistics     Junior      maybe
# 2460       Mrs.     Debra      R    TX  Statistics     Senior         no
#
# [76 rows x 7 columns]

# %%
df123[(df123.skills.isin(['R','SQL','Java'])) & (df123.specialty == 'Statistics') & (df123.state == 'AR')]
# Out:
#      first_name last_name skills state   specialty experience relocation
# 7       Michael    Carter      R    AR  Statistics     Senior        yes
# 11      Michael    Carter    SQL    AR  Statistics     Senior        yes
# 103       James    Mosley      R    AR  Statistics     Junior        yes
# 104       James    Mosley   Java    AR  Statistics     Junior        yes
# 1957     Sandra   Blevins      R    AR  Statistics        Mid      maybe
